# %%
import pandas as pd

# %%
skywest = pd.read_csv("Complete_Updated_M2.csv", encoding='cp1252')
# Out:
# /Users/michelle/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
skywest.head()
# Out:
#   Flgiht Date   Weekday           Carrier  Flight Number  \
# 0    1/1/2009  Thursday  Skywest AIrlines           2554
# 1    1/1/2009  Thursday  Skywest AIrlines           2556
# 2    2/1/2009    Friday  Skywest AIrlines           2550
# 3    2/1/2009    Friday  Skywest AIrlines           2554
# 4    2/1/2009    Friday  Skywest AIrlines           2556
#
#                                       Origin Airport Origin IATA Code  \
# 0  General Mitchell International Airport, Milwau...              MKE
# 1  General Mitchell International Airport, Milwau...              MKE
# 2  General Mitchell International Airport, Milwau...              MKE
# 3  General Mitchell International Airport, Milwau...              MKE
# 4  General Mitchell International Airport, Milwau...              MKE
#
#    Origin Longitude  Origin Latitude  \
# 0        -87.896599        42.947201
# 1        -87.896599        42.947201
# 2        -87.896599        42.947201
# 3        -87.896599        42.947201
# ...

# %%
skywest["Origin_to_Destination"] = skywest["Origin IATA Code"] +" to "+ skywest["Destination IATA Code"]

# %%
Origin_to_Destination
# Out:
# 0        MKE to PHL
# 1        MKE to PHL
# 2        MKE to PHL
# 3        MKE to PHL
# 4        MKE to PHL
#             ...
# 86354    CIC to SFO
# 86355    CIC to SFO
# 86356    CIC to SFO
# 86357    CIC to RDD
# 86358    MDT to ABE
# Length: 86359, dtype: object

# %%
skywest
# Out:
#       Flgiht Date   Weekday           Carrier  Flight Number  \
# 0        1/1/2009  Thursday  Skywest AIrlines           2554
# 1        1/1/2009  Thursday  Skywest AIrlines           2556
# 2        2/1/2009    Friday  Skywest AIrlines           2550
# 3        2/1/2009    Friday  Skywest AIrlines           2554
# 4        2/1/2009    Friday  Skywest AIrlines           2556
# ...           ...       ...               ...            ...
# 86354         NaN    Monday  Skywest AIrlines           5737
# 86355         NaN    Monday  Skywest AIrlines           5790
# 86356         NaN    Monday  Skywest AIrlines           5793
# 86357         NaN    Monday  Skywest AIrlines           5591
# 86358         NaN    Sunday  Skywest AIrlines           5591
#
#                                           Origin Airport Origin IATA Code  \
# 0      General Mitchell International Airport, Milwau...              MKE
# 1      General Mitchell International Airport, Milwau...              MKE
# ...

# %%
skywest.to_csv('skywest.csv')
