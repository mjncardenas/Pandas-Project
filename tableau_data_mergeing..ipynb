# %%
import pandas as pd

# %%
data = pd.read_csv('SS_cleaned.csv')
data.head(5)
# Out:
#     FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  DEP_TIME  \
# 0  1/1/2009         OO               2554    MKE  PHL          1040      1032
# 1  1/1/2009         OO               2555    PHL  MKE          1405      1355
# 2  1/1/2009         OO               2556    MKE  PHL          1555      1554
# 3  1/1/2009         OO               2582    PHL  MKE          1105      1105
# 4  1/1/2009         OO               2620    MKE  MSN          1335      1345
#
#    CRS_ARR_TIME  ARR_TIME  ARR_DELAY flight_status   Weekday cancelled  \
# 0          1340      1320        -20         Early  Thursday        No
# 1          1530      1525         -5         Early  Thursday        No
# 2          1900      1843        -17         Early  Thursday        No
# 3          1230      1224         -6         Early  Thursday        No
# 4          1412      1419          7       Delayed  Thursday        No
#
#                                       Origin Airport  \
# ...

# %%
dest_codes = pd.read_csv('cleaned_airport_codes.csv')
dest_codes.head()
# Out:
#   DEST_CODE  dest_longitude  dest_latitude
# 0       UTK      169.852005      11.222000
# 1       OCA      -80.274803      25.325399
# 2       PQS     -162.899994      61.934601
# 3       CSE     -106.928341      38.851918
# 4       JCY      -98.622498      30.251801

# %%
data.dtypes
# Out:
# FL_DATE                object
# OP_CARRIER             object
# OP_CARRIER_FL_NUM       int64
# ORIGIN                 object
# DEST                   object
# CRS_DEP_TIME            int64
# DEP_TIME                int64
# CRS_ARR_TIME            int64
# ARR_TIME                int64
# ARR_DELAY               int64
# flight_status          object
# Weekday                object
# cancelled              object
# Origin Airport         object
# Destination Airport    object
# DEST_CODE              object
# dtype: object

# %%
dest_codes.dtypes
# Out:
# DEST_CODE          object
# dest_longitude    float64
# dest_latitude     float64
# dtype: object

# %%
# Combine the data into a single dataset.
oo_complete = pd.merge(data, dest_codes, on=["DEST_CODE", "DEST_CODE"])
oo_complete.head()
# Out:
#     FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  DEP_TIME  \
# 0  1/1/2009         OO               2554    MKE  PHL          1040      1032
# 1  1/1/2009         OO               2556    MKE  PHL          1555      1554
# 2  2/1/2009         OO               2550    MKE  PHL           730       744
# 3  2/1/2009         OO               2554    MKE  PHL          1040      1041
# 4  2/1/2009         OO               2556    MKE  PHL          1555      1555
#
#    CRS_ARR_TIME  ARR_TIME  ARR_DELAY flight_status   Weekday cancelled  \
# 0          1340      1320        -20         Early  Thursday        No
# 1          1900      1843        -17         Early  Thursday        No
# 2          1035      1035          0       On Time    Friday        No
# 3          1340      1401         21       Delayed    Friday        No
# 4          1900      1847        -13         Early    Friday        No
#
#                                       Origin Airport  \
# ...

# %%
oo_complete.to_csv('dest_update.csv', index=False)

# %%
data_two = pd.read_csv('dest_update.csv')
data_two.head(5)
# Out:
#    Unnamed: 0   FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN_CODE DEST  \
# 0           0  1/1/2009         OO               2554         MKE  PHL
# 1           1  1/1/2009         OO               2556         MKE  PHL
# 2           2  1/1/2009         OO               2620         MKE  MSN
# 3           3  1/1/2009         OO               2625         MKE  MSN
# 4           4  1/1/2009         OO               2638         MKE  GRR
#
#    CRS_DEP_TIME  DEP_TIME  CRS_ARR_TIME  ARR_TIME  ...  flight_status  \
# 0          1040      1032          1340      1320  ...          Early
# 1          1555      1554          1900      1843  ...          Early
# 2          1335      1345          1412      1419  ...        Delayed
# 3          1605      1600          1643      1643  ...        On Time
# 4          1333      1332          1515      1515  ...        On Time
#
#     Weekday cancelled                                     Origin Airport  \
# ...

# %%
ori = pd.read_csv('dest_update_ii.csv')
ori.head(5)
# Out:
#    Unnamed: 0   FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  \
# 0           0  1/1/2009         OO               2554    MKE  PHL
# 1           1  1/1/2009         OO               2556    MKE  PHL
# 2           2  2/1/2009         OO               2550    MKE  PHL
# 3           3  2/1/2009         OO               2554    MKE  PHL
# 4           4  2/1/2009         OO               2556    MKE  PHL
#
#    CRS_DEP_TIME  DEP_TIME  CRS_ARR_TIME  ARR_TIME  ARR_DELAY flight_status  \
# 0          1040      1032          1340      1320        -20         Early
# 1          1555      1554          1900      1843        -17         Early
# 2           730       744          1035      1035          0       On Time
# 3          1040      1041          1340      1401         21       Delayed
# 4          1555      1555          1900      1847        -13         Early
#
#     Weekday cancelled                                     Origin Airport  \
# ...

# %%
ori_codes = pd.read_csv('cleaned_airport_codes_ii.csv')
ori_codes.head()
# Out:
#   ORIGIN_CODE  origin_longitude  origin_latitude
# 0         UTK        169.852005        11.222000
# 1         OCA        -80.274803        25.325399
# 2         PQS       -162.899994        61.934601
# 3         CSE       -106.928341        38.851918
# 4         JCY        -98.622498        30.251801

# %%
# Combine the data into a single dataset.
merge = pd.merge(ori, ori_codes, on=["ORIGIN_CODE", "ORIGIN_CODE"])
merge.head()
# Out:
#    Unnamed: 0   FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  \
# 0           0  1/1/2009         OO               2554    MKE  PHL
# 1           1  1/1/2009         OO               2556    MKE  PHL
# 2           2  2/1/2009         OO               2550    MKE  PHL
# 3           3  2/1/2009         OO               2554    MKE  PHL
# 4           4  2/1/2009         OO               2556    MKE  PHL
#
#    CRS_DEP_TIME  DEP_TIME  CRS_ARR_TIME  ARR_TIME  ...   Weekday cancelled  \
# 0          1040      1032          1340      1320  ...  Thursday        No
# 1          1555      1554          1900      1843  ...  Thursday        No
# 2           730       744          1035      1035  ...    Friday        No
# 3          1040      1041          1340      1401  ...    Friday        No
# 4          1555      1555          1900      1847  ...    Friday        No
#
#                                       Origin Airport  \
# 0  General Mitchell International Airport, Milwau...
# ...

# %%
merge.to_csv('complete.csv', index=False)
